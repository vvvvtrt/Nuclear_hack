# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('path/to/file.xlsx', sheet_name='Sheet1', header=0)

# %%
df.to_csv('path/to/file.csv', index=False)

# %%
data = pd.read_csv('data\\data.csv')
data.head()
# Out:
#             Станция  Номер линии            Дата  4/3/2024  4/2/2024  \
# 0   Б.Рокоссовского            8  СОКОЛЬНИЧЕСКАЯ     16671     15113
# 1      Черкизовская            8  СОКОЛЬНИЧЕСКАЯ      6248      5441
# 2  Преображенск. пл            8  СОКОЛЬНИЧЕСКАЯ     14094      1132
# 3     Сокольники СЛ            8  СОКОЛЬНИЧЕСКАЯ     18651     10083
# 4    Красносельская            8  СОКОЛЬНИЧЕСКАЯ      7391     19339
#
#    4/1/2024  3/31/2024  3/30/2024  3/29/2024  3/28/2024  ...  1/10/2024  \
# 0      2905      13998      12742       1217      17624  ...       7280
# 1      7991      14864      10015       9721       6623  ...      13486
# 2      6556       7265       4001      10961       6852  ...       8176
# 3      6488       6409       9446      12051      15041  ...       3637
# 4     15424      10725       5965      14682      18134  ...      14194
#
#    1/9/2024  1/8/2024  1/7/2024  1/6/2024  1/5/2024  1/4/2024  1/3/2024  \
# ...

# %%
data.shape
# Out:
# (322, 97)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 97 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Станция      322 non-null    object
#  1   Номер линии  322 non-null    int64
#  2   Дата         322 non-null    object
#  3   4/3/2024     322 non-null    int64
#  4   4/2/2024     322 non-null    int64
#  5   4/1/2024     322 non-null    int64
#  6   3/31/2024    322 non-null    int64
#  7   3/30/2024    322 non-null    int64
#  8   3/29/2024    322 non-null    int64
#  9   3/28/2024    322 non-null    int64
#  10  3/27/2024    322 non-null    int64
#  11  3/26/2024    322 non-null    int64
#  12  3/25/2024    322 non-null    int64
#  13  3/24/2024    322 non-null    int64
#  14  3/23/2024    322 non-null    int64
#  15  3/22/2024    322 non-null    int64
#  16  3/21/2024    322 non-null    int64
#  17  3/20/2024    322 non-null    int64
#  18  3/19/2024    322 non-null    int64
# ...

# %%
data.describe()
# Out:
#        Номер линии      4/3/2024      4/2/2024      4/1/2024     3/31/2024  \
# count   322.000000    322.000000    322.000000    322.000000    322.000000
# mean    600.003106  10541.397516  10773.149068  10646.186335  10891.543478
# std     790.140559   5388.876011   5520.337086   5553.427220   5588.684872
# min       8.000000   1015.000000   1034.000000   1040.000000   1009.000000
# 25%      13.000000   5991.750000   6449.750000   6156.500000   5972.750000
# 50%      17.000000  10463.000000  10842.500000  10422.000000  11045.500000
# 75%    1691.000000  15132.500000  15220.250000  15425.500000  15807.000000
# max    1779.000000  19856.000000  19994.000000  19901.000000  19837.000000
#
#           3/30/2024     3/29/2024     3/28/2024     3/27/2024     3/26/2024  \
# count    322.000000    322.000000    322.000000    322.000000    322.000000
# mean   10224.440994   9896.183230  10816.555901  10417.928571  10487.385093
# ...

# %%
data['Станция'].unique()
# Out:
# array(['Б.Рокоссовского', 'Черкизовская', 'Преображенск. пл',
#        'Сокольники СЛ', 'Красносельская', 'Комсомольск. СЛ',
#        'Красные ворота', 'Чистые пруды', 'Лубянка', 'Охотный ряд',
#        'Кропоткинская', 'Парк культуры СЛ', 'Фрунзенская', 'Спортивная',
#        'Воробьёвы горы', 'Университет', 'Пр-т Вернадск.СЛ',
#        'Юго-западная', 'Красногвардейск.', 'Домодедовская', 'Орехово',
#        'Царицыно', 'Кантемировская', 'Коломенская', 'Автозаводская',
#        'Павелецкая ЗЛ', 'Новокузнецкая', 'Театральная(Зам)', 'Тверская',
#        'Маяковская', 'Белорусская ЗЛ', 'Динамо', 'Аэропорт', 'Сокол',
#        'Войковская', 'Водный Стадион', 'Речной вокзал', 'Каширская',
#        'Каховская', 'Варшавская', 'Киевская АПЛ', 'Смоленская АПЛ',
#        'Арбатская АПЛ', 'Пл. Революции', 'Курская АПЛ', 'Бауманская',
#        'Электрозав-я АПЛ', 'Семёновская', 'Партизанская', 'Измайловская',
#        'Первомайская', 'Щёлковская', 'Александр. сад', 'Арбатская ФЛ',
# ...

# %%
len(data['Станция'].to_list()) == len(data['Станция'].unique())

# %%
data['Станция'].value_counts() == 2
# Out:
# Станция
# Авиамоторная БКЛ     True
# Минская              True
# Раменки              True
# Фонвизинская         True
# Бутырская            True
#                     ...
# Новоясеневская      False
# Ясенево             False
# Тёплый стан         False
# Коньково            False
# Текстильщики СЦ     False
# Name: count, Length: 314, dtype: bool

# %%
len(data['Станция'].to_list())
# Out:
# 322

# %%
# data.loc[data['Станция'] == 'Охотный ряд']['4/3/2024']
data.head()
# Out:
#             Станция  Номер линии            Дата  4/3/2024  4/2/2024  \
# 0   Б.Рокоссовского            8  СОКОЛЬНИЧЕСКАЯ     16671     15113
# 1      Черкизовская            8  СОКОЛЬНИЧЕСКАЯ      6248      5441
# 2  Преображенск. пл            8  СОКОЛЬНИЧЕСКАЯ     14094      1132
# 3     Сокольники СЛ            8  СОКОЛЬНИЧЕСКАЯ     18651     10083
# 4    Красносельская            8  СОКОЛЬНИЧЕСКАЯ      7391     19339
#
#    4/1/2024  3/31/2024  3/30/2024  3/29/2024  3/28/2024  ...  1/10/2024  \
# 0      2905      13998      12742       1217      17624  ...       7280
# 1      7991      14864      10015       9721       6623  ...      13486
# 2      6556       7265       4001      10961       6852  ...       8176
# 3      6488       6409       9446      12051      15041  ...       3637
# 4     15424      10725       5965      14682      18134  ...      14194
#
#    1/9/2024  1/8/2024  1/7/2024  1/6/2024  1/5/2024  1/4/2024  1/3/2024  \
# ...

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/cointegrated/rubert-tiny"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "расскажи что такое arima [MASK]",
})
output

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/meta-llama/Llama-2-7b-chat-hf"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "Can you please let us know more details about your ",
})
output
# Out:
# {'error': 'Model requires a Pro subscription; check out hf.co/pricing to learn more. Make sure to include your HF token in your query.'}

# %%
import requests
import os
from dotenv import load_dotenv
load_dotenv()
BOT_ID = os.environ.get("BOT_ID")
# PORT = os.environ.get("PORT")
USER_ID = os.environ.get("USER_ID")
API_TOKEN = os.environ.get("API_TOKEN")
# DB_NAME = os.environ.get("DB_NAME")

# %%
# """ты - внимательный читатель. Твоя задача - найти в тексте информацию о временной дате. Ключевые слова - вчера, 1 неделю назад, в прошлом месяце. Формат output - только конкретная дата. Сегодняшняя дата - 04/20/2024
# Текст - найди информацию об оттоке пассажиров за последнии 2-3 неделю"""
class Koza_llama_alpaca_lora_flex: 
    def __init__(self, prompt):
        self.prompt = prompt

    def output_date(self):
        url = 'https://api.coze.com/open_api/v2/chat'
        data = {'conversation_id': "123", 
            "bot_id": f"{BOT_ID}",
            "user": f"{USER_ID}",
            "query": self.prompt,
            "stream":False}
        headers = {'Authorization': f'Bearer {API_TOKEN}'}

        response = requests.post(url, data=data, headers=headers)

        return response.json()['messages'][0]['content']

    def output_station(self):
        url = 'https://api.coze.com/open_api/v2/chat'
        data = {'conversation_id': "123", 
            "bot_id": f"{BOT_ID}",
            "user": f"{USER_ID}",
            "query": self.prompt,
            "stream":False}
        headers = {'Authorization': f'Bearer {API_TOKEN}'}

        response = requests.post(url, data=data, headers=headers)

        return response.json()['messages'][0]['content']

    def output_data(self):
        try:
            
            query = pd.Series([data.loc[data['Станция'].lower() == f'{self.output_station()}'.lower()][f'{date}'] for date in self.output_date().split()]).astype(str).str.cat(sep=' ')
            
            return query

        except KeyError:
            print('response...')
        finally:
            print(query)

# %%
part_1 = Koza_llama_alpaca_lora_flex("""ты - внимательный читатель. Твоя задача - найти в тексте информацию о временной дате. Ключевые слова - вчера, 1 неделю назад, в прошлом месяце. Формат output - только конкретная дата, выведи все даты. Сегодняшняя дата - 04/03/2024, ее формат М/ДД/ГГГГ.
Текст - найди информацию об оттоке пассажиров за последний месяц, выведи все даты""")
# data.loc[data['Станция'] == f'{part_1.output_station()}'][f'{part_1.output_date()}']
part_1.output_date()
# Out:
# '03/03/2024\n02/07/2024\n02/04/2024'

# %%
print('well done')
